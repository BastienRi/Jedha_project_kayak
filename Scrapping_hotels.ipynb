# %% [markdown]
# # Scrapping hotels info

# %% [markdown]
# <b>Scrape Booking.com</b>
#
# Since BookingHoldings doesn't have aggregated databases, it will be much faster to scrape data directly from booking.com
#
# You can scrap as many information asyou want, but we suggest that you get at least:
#
# - hotel name
# - Url to its booking.com page,
# - Its coordinates: latitude and longitude
# - Score given by the website users
# - Text description of the hotel

# %% [raw]
# *** all infos except latt/long can be scrapped form the "welcome" page ***
#
#
# *** Latt / long : can be scrapped in each hotel page ***
#
# <a id="hotel_header" class="jq_tooltip loc_block_link_underline_fix
# bui-link
# show_on_map_hp_link
# " href="#map_opened-hotel_header" data-atlas-latlng="48.87083380,2.34485720" data-atlas-bbox="48.8528683834269,2.31749373297899,48.8887992165731,2.37222066702097" data-source="top_link" data-width="300" style="white-space:nowrap" role="button" data-title="Hotel des Grands Boulevards, Paris - Vérifier l'emplacement" aria-describedby="materialized_tooltip_2t63q">
# Excellent emplacement - voir la carte
# </a>

# %% [markdown]
# ## Création du DataFrame des URLs (de la page d'accueil de chaque ville)

# %%
city_names = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
url_mont_saint_michel = "https://www.booking.com/searchresults.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQKIAgGoAgO4Aqndno0GwAIB0gIkOTM3NmUyNmQtNjJhMC00NzI2LTliMTYtM2I1NDk1NDg1MjAy2AIF4AIB&sid=a33dd63e1835e1ec9af64c715c2bc273&aid=304142&src=searchresults&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.fr.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQKIAgGoAgO4Aqndno0GwAIB0gIkOTM3NmUyNmQtNjJhMC00NzI2LTliMTYtM2I1NDk1NDg1MjAy2AIF4AIB%3Bsid%3Da33dd63e1835e1ec9af64c715c2bc273%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bclass_interval%3D1%3Bdest_id%3D-1456928%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Biata%3DPAR%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dindex%3Bsrc_elem%3Dsb%3Bsrpvid%3D2f5479ecc1720166%3Bss%3DParis%252C%2520%25C3%258Ele-de-France%252C%2520France%3Bss_all%3D0%3Bss_raw%3Dparis%3Bssb%3Dempty%3Bsshis%3D0%3Btop_ufis%3D1%26%3B&ss=Le+Mont-Saint-Michel%2C+Basse-Normandie%2C+France&is_ski_area=&ssne=Paris&ssne_untouched=Paris&city=-1456928&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=Mont+saint+&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=900039327&dest_type=city&place_id_lat=48.636&place_id_lon=-1.511&search_pageview_id=2f5479ecc1720166&search_selected=true&search_pageview_id=2f5479ecc1720166&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0&nflt=ht_id%3D204"
url_saint_malo =        "https://www.booking.com/searchresults.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQKIAgGoAgO4Aqndno0GwAIB0gIkOTM3NmUyNmQtNjJhMC00NzI2LTliMTYtM2I1NDk1NDg1MjAy2AIF4AIB&sid=a33dd63e1835e1ec9af64c715c2bc273&aid=304142&src=searchresults&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.fr.html%3Faid%3D304142%3Blabel%3Dgen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24ARfIAQzYAQHoAQH4AQKIAgGoAgO4Aqndno0GwAIB0gIkOTM3NmUyNmQtNjJhMC00NzI2LTliMTYtM2I1NDk1NDg1MjAy2AIF4AIB%3Bsid%3Da33dd63e1835e1ec9af64c715c2bc273%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcity%3D-1456928%3Bclass_interval%3D1%3Bdest_id%3D900039327%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D83f67c62a2050151%3Bss%3DLe%2520Mont-Saint-Michel%252C%2520Basse-Normandie%252C%2520France%3Bss_all%3D0%3Bss_raw%3DMont%2520saint%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DParis%3Bssne_untouched%3DParis%3Btop_ufis%3D1%26%3B&ss=Saint-Malo%2C+Bretagne%2C+France&is_ski_area=&ssne=Le+Mont-Saint-Michel&ssne_untouched=Le+Mont-Saint-Michel&city=900039327&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=Saint+ma&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-
3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DBiarritz%3Bssne_untouched%3DBiarritz%3Btop_ufis%3D1%26%3B&ss=La+Rochelle%2C+Poitou-Charentes%2C+France&is_ski_area=&ssne=Bayonne&ssne_untouched=Bayonne&city=-1410844&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&from_sf=1&ss_raw=la+roc&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-1438604&dest_type=city&iata=LRH&place_id_lat=46.15911&place_id_lon=-1.15204&search_pageview_id=b5da31667363013d&search_selected=true&search_pageview_id=b5da31667363013d&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0&nflt=ht_id%3D204"

# %%
urls_page_city_hotels = [
    url_mont_saint_michel,
    url_saint_malo,
    url_bayeux,
    url_le_havre,
    url_rouen,
    url_paris,
    url_amiens,
    url_lille,
    url_strasbourg,
    url_chateau_du_haut_koenigsbourg,
    url_colmar,
    url_eguisheim,
    url_besançon,
    url_dijon,
    url_annecy,
    url_grenoble,
    url_lyon,
    url_gorges_du_verdon,
    url_bormes_les_mimosas,
    url_cassis,
    url_marseille,
    url_aix_en_provence,
    url_avignon,
    url_uzes,
    url_nimes,
    url_aigues_mortes,
    url_saintes_maries_de_la_mer,
    url_collioure,
    url_carcassonne,
    url_ariege,
    url_toulouse,
    url_montauban,
    url_biarritz,
    url_bayonne,
    url_la_rochelle
]

# %%
import pandas as pd
dictionary = {'cities' : city_names, 'urls_page_city_hotels' : urls_page_city_hotels}
df_page_ville_hotels = pd.DataFrame(data = dictionary)
df_page_ville_hotels
# Out:
#                           cities  \
# 0              Mont Saint Michel
# 1                        St Malo
# 2                         Bayeux
# 3                       Le Havre
# 4                          Rouen
# 5                          Paris
# 6                         Amiens
# 7                          Lille
# 8                     Strasbourg
# 9   Chateau du Haut Koenigsbourg
# 10                        Colmar
# 11                     Eguisheim
# 12                      Besancon
# 13                         Dijon
# 14                        Annecy
# 15                      Grenoble
# 16                          Lyon
# 17              Gorges du Verdon
# 18            Bormes les Mimosas
# 19                        Cassis
# 20                     Marseille
# 21               Aix en Provence
# 22                       Avignon
# 23                          Uzes
# 24                         Nimes
# 25                 Aigues Mortes
# 26      Saintes Maries de la mer
# ...

# %% [markdown]
# ## Scrapping hotel infos from local downloaded html file

# %% [markdown]
# ### Html files downloads and soup creations

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
#### WEB PAGES DOWNLOAD, not necessary to launch if files are already dowloaded  #####

if input('Are you sure you want to download web pages ? (y for yes, anything else to cancel') =='y' :
    reqs = []
    for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,1])):
        url_page_ville = df_page_ville_hotels.iloc[i,1]
        reqs.append(requests.get(url_page_ville))
        with open('pages/page{}.html'.format(i), 'w') as f:
            f.write(reqs[i].text)
else :
    print('Downloads canceled.')
# Out:
# Are you sure you want to download web pages ? (y for yes, anything else to cancel n
# Downloads canceled.

# %%
soups = []
    
for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,1])) :
    f=open("pages/page{}.html".format(i), 'r')
    soups.append(BeautifulSoup(f))
# Out:
# 35it [00:10,  3.41it/s]

# %% [markdown]
# ### DataFrame creation

# %%
columns_df = ['city_id', 'city_name', 'hotel_id', 'hotel_name', 'hotel_url', 'hotel_score', 'hotel_text']

df_cities_and_hotels = pd.DataFrame(columns = columns_df)
df_cities_and_hotels
# Out:
# Empty DataFrame
# Columns: [city_id, city_name, hotel_id, hotel_name, hotel_url, hotel_score, hotel_text]
# Index: []

# %% [markdown]
# ### Names

# %%
# check if name scrapping is ok
hotel_names = []
for element in soups[0].select("span.bui-card__title"):
    if element.get('itemprop') =='name' :
        hotel_names.append(element.get_text()[1:-1])
hotel_names
# Out:
# ['Les Terrasses Poulard',
#  'Le Relais Saint Michel',
#  'Hotel De La Digue',
#  'La Mère Poulard',
#  'Hôtel Vert',
#  'Le Mouton Blanc',
#  'Mercure Mont Saint Michel',
#  'La Vieille Auberge',
#  'Le Saint Aubert',
#  'Hotel Gabriel']

# %%
# double loop for dataframe writing :

df_cities_and_hotels = df_cities_and_hotels[0:0]
id_hotel = 0

for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,0])) :
    id_hotel = 0
    for k, l in enumerate(soups[i].select("span.bui-card__title")) :
        if l.get('itemprop') =='name' :
            df_cities_and_hotels = df_cities_and_hotels.append(other = {'city_id':i, 'city_name':j,'hotel_id':id_hotel,'hotel_name':l.get_text()[1:-1]}, ignore_index = True)
            id_hotel+=1

        
    
df_cities_and_hotels
# Out:
# 35it [00:02, 12.95it/s]
#     city_id          city_name hotel_id  \
# 0         0  Mont Saint Michel        0
# 1         0  Mont Saint Michel        1
# 2         0  Mont Saint Michel        2
# 3         0  Mont Saint Michel        3
# 4         0  Mont Saint Michel        4
# ..      ...                ...      ...
# 305      34        La Rochelle        5
# 306      34        La Rochelle        6
# 307      34        La Rochelle        7
# 308      34        La Rochelle        8
# 309      34        La Rochelle        9
#
#                                             hotel_name hotel_url hotel_score  \
# 0                                Les Terrasses Poulard       NaN         NaN
# 1                               Le Relais Saint Michel       NaN         NaN
# 2                                    Hotel De La Digue       NaN         NaN
# 3                                      La Mère Poulard       NaN         NaN
# ...

# %% [markdown]
# ### URLs

# %%
#<a data-et-click="customGoal:OATBaQJbVTbZXWSYHCSdUWAUC:2" data-lp-ga-click="sr-snippet:click-title:1" href="/hotel/fr/les-terrasses-poulard.fr.html?sid=8f123c4823fb123de26580f02aa57e5a" title="Les Terrasses Poulard - 
#Hôtel au Mont-Saint-Michel 
#">

#for element in soup.select("body div#bodyconstraint-inner a"):
    #print(element.get('data-testid'))

#for element in soup.select("body div#bodyconstraint div#bodyconstraint-inner div"):
 #   print(element)

#for element in soup.select("span.bui-card__title"):
   # if element.get('itemprop') =='name' :
     #   print(1)

# %%
#check if url scrapping ok:

urls = []
for element in soups[0].select("a"):
    if element.get('data-et-click')== "customGoal:OATBaQJbVTbZXWSYHCSdUWAUC:2" :
        urls.append(element.get('href'))
        
url_top = 'https://www.booking.com/'
urls = [url_top+x for x in urls]
urls
# Out:
# ['https://www.booking.com//hotel/fr/les-terrasses-poulard.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/le-relais-saint-michel.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/de-la-digue.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/la-mere-poulard.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/vert.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/le-mouton-blanc-le-mont-saint-michel.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/mont-saint-michel.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/la-vieille-auberge-le-mont-saint-michel.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
#  'https://www.booking.com//hotel/fr/hotel-saint-aubert.fr.html?sid=48b6b88c851159d155f50901d669cc1e',
# ...

# %%
for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,0])) :
    id_hotel = 0
    for k, l in enumerate(soups[i].select("a")) :
        if l.get('data-et-click') == "customGoal:OATBaQJbVTbZXWSYHCSdUWAUC:2" :
            df_cities_and_hotels.loc[ (df_cities_and_hotels.city_id == i) & (df_cities_and_hotels.hotel_id == id_hotel), 'hotel_url'] = 'https://www.booking.com/' + l.get('href')
            id_hotel+=1

df_cities_and_hotels
# Out:
# 35it [00:01, 29.84it/s]
#     city_id          city_name hotel_id  \
# 0         0  Mont Saint Michel        0
# 1         0  Mont Saint Michel        1
# 2         0  Mont Saint Michel        2
# 3         0  Mont Saint Michel        3
# 4         0  Mont Saint Michel        4
# ..      ...                ...      ...
# 305      34        La Rochelle        5
# 306      34        La Rochelle        6
# 307      34        La Rochelle        7
# 308      34        La Rochelle        8
# 309      34        La Rochelle        9
#
#                                             hotel_name  \
# 0                                Les Terrasses Poulard
# 1                               Le Relais Saint Michel
# 2                                    Hotel De La Digue
# 3                                      La Mère Poulard
# 4                                           Hôtel Vert
# ..                                                 ...
# 305                     ibis Styles La Rochelle Centre
# ...

# %% [markdown]
# ### Score given by website users

# %%
# check :
user_scores = []
for element in soups[0].select("div"):
    if element.get('aria-label') != None :
        if element.get('aria-label')[:13] == "Avec une note"  :
            score = float(element.get('aria-label')[-3:].replace(',','.'))
            user_scores.append(score)
user_scores
# Out:
# [7.3, 7.8, 7.1, 7.2, 8.1, 7.2, 8.2, 7.4, 7.3, 8.1]

# %%
for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,0])) :
    id_hotel = 0
    for k, l in enumerate(soups[i].select("div")) :
        if type(l.get('aria-label')) == str :
        
            if l.get('aria-label')[:13] == "Avec une note"  :
                # 2 cas : soit la note est entière (exemple '7'), dans ce cas le string de 'aria-label' est de taille 18
                # sinon, la note est affichée avec un chiffre après la virgule, dans ce cas 'aria-label' est de taille 20
                
                if len(l.get('aria-label')) == 20 :
                    df_cities_and_hotels.loc[ (df_cities_and_hotels.city_id == i) & (df_cities_and_hotels.hotel_id == id_hotel), 'hotel_score'] = float(l.get('aria-label')[-3:].replace(',','.'))
                    id_hotel+=1
                    
                elif len(l.get('aria-label')) == 18 :
                    df_cities_and_hotels.loc[ (df_cities_and_hotels.city_id == i) & (df_cities_and_hotels.hotel_id == id_hotel), 'hotel_score'] = float(l.get('aria-label')[-1:].replace(',','.'))
                    id_hotel+=1

df_cities_and_hotels
# Out:
# 35it [00:01, 22.16it/s]
#     city_id          city_name hotel_id  \
# 0         0  Mont Saint Michel        0
# 1         0  Mont Saint Michel        1
# 2         0  Mont Saint Michel        2
# 3         0  Mont Saint Michel        3
# 4         0  Mont Saint Michel        4
# ..      ...                ...      ...
# 305      34        La Rochelle        5
# 306      34        La Rochelle        6
# 307      34        La Rochelle        7
# 308      34        La Rochelle        8
# 309      34        La Rochelle        9
#
#                                             hotel_name  \
# 0                                Les Terrasses Poulard
# 1                               Le Relais Saint Michel
# 2                                    Hotel De La Digue
# 3                                      La Mère Poulard
# 4                                           Hôtel Vert
# ..                                                 ...
# 305                     ibis Styles La Rochelle Centre
# ...

# %% [markdown]
# ### Text description of the hotel

# %%
# test

user_scores = []

for element in soups[0].select("div.sr__card_main div p")[:3]:
    if element.get_text() != "Hébergement géré par un particulier" :
        print(element.get_text())
        print()
# ok mais impossible de dissocier la description et les commentaires. de plus la description a l'air tronquée.
# Out:
# Occupant 2 bâtiments différents au cœur du Mont-Saint-Michel, l'établissement historique Les Terrasses Poulard propose des hébergements avec une vue sur la baie, le village et la rue.
# Très agréable et très aidant !!
#
#
#
# Le Relais Saint Michel vous accueille face à la baie du Mont-Saint-Michel.
# Tout ! L hotel est tres  beau le personnel serviable et souriant..le cadre est magnifique - nous avions une suite avec un grand balcon donnant une vue magnifique sur Le Mont Saint Michel.
#
#
#
# L'hôtel De La Digue est un établissement traditionnel situé en Normandie, à seulement 5 minutes en navette ou à 30 minutes de marche du Mont-Saint-Michel.
# ...

# %%
for i, j in tqdm(enumerate(df_page_ville_hotels.iloc[:,0])) :
    id_hotel = 0
    for k, l in enumerate(soups[i].select("div.sr__card_main div p")) :
        if l.get_text() != "Hébergement géré par un particulier" :
            df_cities_and_hotels.loc[ (df_cities_and_hotels.city_id == i) & (df_cities_and_hotels.hotel_id == id_hotel), 'hotel_text'] = l.get_text()
            id_hotel+=1

df_cities_and_hotels
# Out:
# 35it [00:03, 10.71it/s]
#     city_id          city_name hotel_id  \
# 0         0  Mont Saint Michel        0
# 1         0  Mont Saint Michel        1
# 2         0  Mont Saint Michel        2
# 3         0  Mont Saint Michel        3
# 4         0  Mont Saint Michel        4
# ..      ...                ...      ...
# 305      34        La Rochelle        5
# 306      34        La Rochelle        6
# 307      34        La Rochelle        7
# 308      34        La Rochelle        8
# 309      34        La Rochelle        9
#
#                                             hotel_name  \
# 0                                Les Terrasses Poulard
# 1                               Le Relais Saint Michel
# 2                                    Hotel De La Digue
# 3                                      La Mère Poulard
# 4                                           Hôtel Vert
# ..                                                 ...
# 305                     ibis Styles La Rochelle Centre
# ...

# %% [markdown]
# ### Coordinates

# %% [markdown]
# #### Test on one case :
# Let's try on just one hotel to begin with :

# %%
hotel_url = df_cities_and_hotels['hotel_url'].iloc[0]

# %%
hotel_url
# Out:
# 'https://www.booking.com//hotel/fr/les-terrasses-poulard.fr.html?sid=48b6b88c851159d155f50901d669cc1e'

# %%
req_test = requests.get(hotel_url)

with open('pages/hotels_pages/test.html', 'w') as f:
    f.write(req_test.text)

f=open("pages/hotels_pages/test.html", 'r')
soup_test = BeautifulSoup(f)

# %%
soup_test.select("a#hotel_header")
# Out:
# [<a class="jq_tooltip loc_block_link_underline_fix bui-link show_on_map_hp_link" data-atlas-bbox="48.6173840090681,-1.53761423137484,48.6533148422143,-1.48314320537748" data-atlas-latlng="48.63534943,-1.51037872" data-source="top_link" data-width="300" href="#map_opened-hotel_header" id="hotel_header" role="button" style="white-space:nowrap" title="Les Terrasses Poulard, Le Mont-Saint-Michel - Vérifier l'emplacement">
#  Excellent emplacement - voir la carte
#  </a>]

# %% [raw]
# <a id="hotel_header" class="jq_tooltip loc_block_link_underline_fix
# bui-link
# show_on_map_hp_link
# " href="#map_opened-hotel_header" data-atlas-latlng="48.63534943,-1.51037872" data-atlas-bbox="48.6173840090681,-1.53761423137484,48.6533148422143,-1.48314320537748" data-source="top_link" data-width="300" title="Les Terrasses Poulard, Le Mont-Saint-Michel - Vérifier l'emplacement" style="white-space:nowrap" role="button">
# Excellent emplacement - voir la carte
# </a>

# %%
lattitude, longitude = soup_test.select("a#hotel_header")[0].get("data-atlas-latlng").split(',')
print("Lattitude :", lattitude)
print("Longitude :", longitude)
# Out:
# Lattitude : 48.63534943
# Longitude : -1.51037872

# %% [markdown]
# #### Idem with a loop :

# %%
# creation of columns 'lattitude' and 'longitude' in dataframe "df_cities_and_hotels" :
import numpy as np
df_cities_and_hotels["lattitude"] = np.nan
df_cities_and_hotels["longitude"] = np.nan
df_cities_and_hotels.head()
# Out:
#   city_id          city_name hotel_id              hotel_name  \
# 0       0  Mont Saint Michel        0   Les Terrasses Poulard
# 1       0  Mont Saint Michel        1  Le Relais Saint Michel
# 2       0  Mont Saint Michel        2       Hotel De La Digue
# 3       0  Mont Saint Michel        3         La Mère Poulard
# 4       0  Mont Saint Michel        4              Hôtel Vert
#
#                                            hotel_url hotel_score  \
# 0  https://www.booking.com//hotel/fr/les-terrasse...         7.3
# 1  https://www.booking.com//hotel/fr/le-relais-sa...         7.8
# 2  https://www.booking.com//hotel/fr/de-la-digue....         7.1
# 3  https://www.booking.com//hotel/fr/la-mere-poul...         7.2
# 4  https://www.booking.com//hotel/fr/vert.fr.html...         8.1
#
#                                           hotel_text  lattitude  longitude
# 0  \nOccupant 2 bâtiments différents au cœur du M...        NaN        NaN
# ...

# %%
# téléchargements de toutes les pages des hotels

#### WEB PAGES DOWNLOAD FOR EACH HOTEL, not necessary to launch if files are already dowloaded  #####
import time

if input('Are you sure you want to download web pages ? (y for yes, anything else to cancel') =='y' :
    reqs_all_hotels = []
    for i, j in tqdm(enumerate(df_cities_and_hotels.iloc[:,0])):
        url_hotel = df_cities_and_hotels.iloc[i,4]
        reqs_all_hotels.append(requests.get(url_hotel))
        with open('pages/hotels_pages/page_hotel{}.html'.format(i), 'w') as f:
            f.write(reqs_all_hotels[i].text)
        time.sleep(0.5)
else :
    print('Downloads canceled.')
# Out:
# Are you sure you want to download web pages ? (y for yes, anything else to cancel y
# 243it [10:07,  2.54s/it]
